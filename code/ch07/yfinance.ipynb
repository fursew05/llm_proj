# %% [markdown]
# ### yfinance
# - 야후 파이낸스의 금융 데이터를 가져올 수 있게 하는 오픈소스 라이브러리
# - 주가, 재무지표, 거래량 등 다양한 데이터를 얻을 수 있음

# %%
import yfinance as yf

# 금융상품을 식별하는 코드를 통해 티커 객체를 생성
ts = yf.Ticker('TSLA')
display(ts.info)
# Out:
# {'address1': '1 Tesla Road',
#  'city': 'Austin',
#  'state': 'TX',
#  'zip': '78725',
#  'country': 'United States',
#  'phone': '512 516 8177',
#  'website': 'https://www.tesla.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
# 최근 주가 확인하기(ticker.history로 확인) -> 데이터프레임 형태로 ohlcv 데이터가 주어짐
hist = ts.history(period='1y')
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-08-07 00:00:00-04:00  200.770004  203.490005  191.479996  191.759995
# 2024-08-08 00:00:00-04:00  195.699997  200.699997  192.039993  198.839996
# 2024-08-09 00:00:00-04:00  197.050003  200.880005  195.110001  200.000000
# 2024-08-12 00:00:00-04:00  199.020004  199.259995  194.669998  197.490005
# 2024-08-13 00:00:00-04:00  198.470001  208.490005  197.059998  207.830002
# ...                               ...         ...         ...         ...
# 2025-07-31 00:00:00-04:00  319.609985  321.369995  306.100006  308.269989
# 2025-08-01 00:00:00-04:00  306.209991  309.309998  297.820007  302.630005
# 2025-08-04 00:00:00-04:00  309.079987  312.119995  303.000000  309.260010
# 2025-08-05 00:00:00-04:00  308.950012  312.450012  305.500000  308.720001
# 2025-08-06 00:00:00-04:00  307.890015  320.470001  306.929993  319.910004
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
# 해당 금융상품에 대한 전문가의 의견을 데이터로 확인할 수 있음(recommendations 속성)
ts.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          5   13    19     7           2
# 1    -1m          5   13    18     7           3
# 2    -2m          7   14    16     7           3
# 3    -3m          7   16    14     8           3
